# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    "../datasets/customer_ml_dataset_cleaned.csv"
)

# %%
df.head()
# Out:
#    customer_id  total_sessions  total_orders  total_spend  \
# 0         1000               2             1      1228.72
# 1         1001               1             0         0.00
# 2         1002               3             0         0.00
# 3         1003               3             1      1681.96
# 4         1004               3             0         0.00
#
#    average_order_value  cart_abandonment_rate  average_discount_used  \
# 0              1228.72                   0.50                  17.50
# 1              1399.00                   0.00                   0.00
# 2              1399.00                   0.67                   3.33
# 3              1681.96                   0.00                  11.67
# 4              1399.00                   0.33                  16.67
#
#    customer_satisfaction  preferred_device  city  preferred_category  \
# 0                   3.50                 1   204                   7
# 1                   4.00                 0   101                   3
# 2                   4.00                 1    90                   6
# 3                   4.33                 1    87                   4
# 4                   4.00                 1    97                   5
#
#    total_products_purchased  total_pages_viewed  average_time_on_site  \
# 0                         7                  35               1014.00
# 1                         4                  15                996.00
# 2                         8                  25                313.67
# 3                         9                  17                695.33
# 4                         5                  37                923.67
#
#    total_review_votes  preferred_payment_method  rn  churn
# 0                  44                         4   1      0
# 1                   0                         4   2      0
# 2                   0                         5   3      0
# 3                   4                         2   4      0
# 4                   0                         5   5      0

# %%
df.shape
# Out:
# (1000, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               1000 non-null   int64
#  1   total_sessions            1000 non-null   int64
#  2   total_orders              1000 non-null   int64
#  3   total_spend               1000 non-null   float64
#  4   average_order_value       1000 non-null   float64
#  5   cart_abandonment_rate     1000 non-null   float64
#  6   average_discount_used     1000 non-null   float64
#  7   customer_satisfaction     1000 non-null   float64
#  8   preferred_device          1000 non-null   int64
#  9   city                      1000 non-null   int64
#  10  preferred_category        1000 non-null   int64
#  11  total_products_purchased  1000 non-null   int64
#  12  total_pages_viewed        1000 non-null   int64
#  13  average_time_on_site      1000 non-null   float64
#  14  total_review_votes        1000 non-null   int64
#  15  preferred_payment_method  1000 non-null   int64
#  16  rn                        1000 non-null   int64
#  17  churn                     1000 non-null   int64
# dtypes: float64(6), int64(12)
# memory usage: 140.8 KB

# %%
df.describe()
# Out:
#        customer_id  total_sessions  total_orders   total_spend  \
# count  1000.000000     1000.000000   1000.000000   1000.000000
# mean   1524.031000        2.915000      0.670000   1199.307420
# std     303.457926        1.487275      0.820837   1905.880101
# min    1000.000000        1.000000      0.000000      0.000000
# 25%    1261.750000        2.000000      0.000000      0.000000
# 50%    1524.500000        3.000000      0.000000      0.000000
# 75%    1785.250000        4.000000      1.000000   1824.170000
# max    2048.000000        8.000000      5.000000  13800.960000
#
#        average_order_value  cart_abandonment_rate  average_discount_used  \
# count          1000.000000            1000.000000            1000.000000
# mean           1606.805560               0.411710               9.057800
# std             998.652549               0.327058               6.224389
# min              90.970000               0.000000               0.000000
# 25%            1399.000000               0.000000               5.000000
# 50%            1399.000000               0.400000               8.750000
# 75%            1399.000000               0.600000              12.500000
# max            7889.360000               1.000000              30.000000
#
#        customer_satisfaction  preferred_device         city  \
# count            1000.000000        1000.00000  1000.000000
# mean                3.956580           1.14200    94.349000
# std                 0.342832           0.60349    62.835241
# min                 2.000000           0.00000     2.000000
# 25%                 4.000000           1.00000    48.000000
# 50%                 4.000000           1.00000    80.000000
# 75%                 4.000000           2.00000   136.000000
# max                 5.000000           2.00000   224.000000
#
#        preferred_category  total_products_purchased  total_pages_viewed  \
# count         1000.000000               1000.000000         1000.000000
# mean             5.119000                  7.342000           36.759000
# std              1.854259                  4.221001           22.379181
# min              0.000000                  1.000000            1.000000
# 25%              4.000000                  4.000000           20.750000
# 50%              6.000000                  7.000000           34.000000
# 75%              7.000000                 10.000000           50.000000
# max              7.000000                 24.000000          134.000000
#
#        average_time_on_site  total_review_votes  preferred_payment_method  \
# count           1000.000000         1000.000000               1000.000000
# mean             911.943910           16.589000                  3.659000
# std              348.861867           22.903114                  1.459743
# min               34.000000            0.000000                  0.000000
# 25%              691.750000            0.000000                  3.000000
# 50%              925.450000            0.000000                  4.000000
# 75%             1122.082500           31.000000                  5.000000
# max             1758.000000          126.000000                  5.000000
#
#                 rn        churn
# count  1000.000000  1000.000000
# mean    500.500000     0.109000
# std     288.819436     0.311795
# min       1.000000     0.000000
# 25%     250.750000     0.000000
# 50%     500.500000     0.000000
# 75%     750.250000     0.000000
# max    1000.000000     1.000000

# %%
df["churn"].value_counts()
# Out:
# churn
# 0    891
# 1    109
# Name: count, dtype: int64

# %%
df["churn"].value_counts(
    normalize=True
) * 100
# Out:
# churn
# 0    89.1
# 1    10.9
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8,5))

df["churn"].value_counts().plot(
    kind="bar"
)

plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["total_spend"],
    bins=30
)

plt.title("Customer Total Spend Distribution")
plt.xlabel("Total Spend")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["total_orders"],
    bins=20
)

plt.title("Total Orders Distribution")
plt.xlabel("Orders")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["customer_satisfaction"],
    bins=20
)

plt.title("Customer Satisfaction Distribution")
plt.xlabel("Customer Satisfaction")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["customer_satisfaction"],
    bins=20
)

plt.title("Customer Satisfaction Distribution")
plt.xlabel("Customer Satisfaction")
plt.ylabel("Customers")

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["average_discount_used"],
    bins=20
)

plt.title("Average Discount Usage")
plt.xlabel("Discount Percentage")
plt.ylabel("Customers")

plt.show()

# %%
df.groupby(
    "churn"
)["total_spend"].mean()
# Out:
# churn
# 0    1213.753165
# 1    1081.223394
# Name: total_spend, dtype: float64

# %%
df.groupby(
    "churn"
)["total_orders"].mean()
# Out:
# churn
# 0    0.676768
# 1    0.614679
# Name: total_orders, dtype: float64

# %%
df.groupby(
    "churn"
)["cart_abandonment_rate"].mean()
# Out:
# churn
# 0    0.40844
# 1    0.43844
# Name: cart_abandonment_rate, dtype: float64

# %%
df.groupby(
    "churn"
)["customer_satisfaction"].mean()
# Out:
# churn
# 0    3.960449
# 1    3.924954
# Name: customer_satisfaction, dtype: float64

# %%
df.groupby(
    "churn"
)["average_time_on_site"].mean()
# Out:
# churn
# 0    905.293793
# 1    966.304037
# Name: average_time_on_site, dtype: float64

# %%
df.groupby(
    "churn"
)["total_products_purchased"].mean()
# Out:
# churn
# 0    7.375982
# 1    7.064220
# Name: total_products_purchased, dtype: float64

# %%
correlation_matrix = df.corr(
    numeric_only=True
)

correlation_matrix
# Out:
#                           customer_id  total_sessions  total_orders  \
# customer_id                  1.000000       -0.033205     -0.013144
# total_sessions              -0.033205        1.000000      0.471429
# total_orders                -0.013144        0.471429      1.000000
# total_spend                 -0.011475        0.357371      0.755013
# average_order_value         -0.012943        0.081524      0.149892
# cart_abandonment_rate        0.029000       -0.072591     -0.353908
# average_discount_used        0.031381       -0.009012     -0.059708
# customer_satisfaction        0.010021        0.002649     -0.117451
# preferred_device            -0.011557        0.351383      0.181582
# city                        -0.003719       -0.202821     -0.126186
# preferred_category           0.003405        0.441052      0.223785
# total_products_purchased    -0.032561        0.890227      0.393454
# total_pages_viewed          -0.005133        0.844328      0.398417
# average_time_on_site         0.010810       -0.013656      0.004388
# total_review_votes          -0.009475        0.451732      0.865153
# preferred_payment_method    -0.029127        0.428802      0.221777
# rn                           0.999993       -0.033364     -0.013317
# churn                        0.044218       -0.044759     -0.023584
#
#                           total_spend  average_order_value  \
# customer_id                 -0.011475            -0.012943
# total_sessions               0.357371             0.081524
# total_orders                 0.755013             0.149892
# total_spend                  1.000000             0.712698
# average_order_value          0.712698             1.000000
# cart_abandonment_rate       -0.288971            -0.097902
# average_discount_used       -0.107664            -0.092160
# customer_satisfaction       -0.107147             0.034490
# preferred_device             0.160916             0.075162
# city                        -0.092669            -0.000096
# preferred_category           0.168947             0.039519
# total_products_purchased     0.390173             0.197858
# total_pages_viewed           0.300064             0.062238
# average_time_on_site         0.015543             0.015705
# total_review_votes           0.627575             0.107155
# preferred_payment_method     0.169375             0.046351
# rn                          -0.011658            -0.013034
# churn                       -0.021681            -0.007878
#
#                           cart_abandonment_rate  average_discount_used  \
# customer_id                            0.029000               0.031381
# total_sessions                        -0.072591              -0.009012
# total_orders                          -0.353908              -0.059708
# total_spend                           -0.288971              -0.107664
# average_order_value                   -0.097902              -0.092160
# cart_abandonment_rate                  1.000000               0.068198
# average_discount_used                  0.068198               1.000000
# customer_satisfaction                  0.079120               0.079947
# preferred_device                      -0.044695               0.010066
# city                                   0.014661               0.038645
# preferred_category                    -0.048913              -0.035183
# total_products_purchased              -0.060426              -0.009070
# total_pages_viewed                    -0.056957              -0.007870
# average_time_on_site                   0.019637               0.010537
# total_review_votes                    -0.300534              -0.036809
# preferred_payment_method              -0.098580              -0.071125
# rn                                     0.029248               0.031422
# churn                                  0.028600              -0.030715
#
#                           customer_satisfaction  preferred_device      city  \
# customer_id                            0.010021         -0.011557 -0.003719
# total_sessions                         0.002649          0.351383 -0.202821
# total_orders                          -0.117451          0.181582 -0.126186
# total_spend                           -0.107147          0.160916 -0.092669
# average_order_value                    0.034490          0.075162 -0.000096
# cart_abandonment_rate                  0.079120         -0.044695  0.014661
# average_discount_used                  0.079947          0.010066  0.038645
# customer_satisfaction                  1.000000          0.011349  0.040369
# preferred_device                       0.011349          1.000000 -0.126221
# city                                   0.040369         -0.126221  1.000000
# preferred_category                    -0.037040          0.177208 -0.114690
# total_products_purchased              -0.000872          0.308645 -0.195750
# total_pages_viewed                    -0.011773          0.307381 -0.165364
# average_time_on_site                  -0.000125         -0.071594 -0.072877
# total_review_votes                    -0.109113          0.164714 -0.122113
# preferred_payment_method              -0.031076          0.199330 -0.124488
# rn                                     0.009926         -0.011566 -0.003661
# churn                                 -0.032281          0.013417 -0.012316
#
#                           preferred_category  total_products_purchased  \
# customer_id                         0.003405                 -0.032561
# total_sessions                      0.441052                  0.890227
# total_orders                        0.223785                  0.393454
# total_spend                         0.168947                  0.390173
# average_order_value                 0.039519                  0.197858
# cart_abandonment_rate              -0.048913                 -0.060426
# average_discount_used              -0.035183                 -0.009070
# customer_satisfaction              -0.037040                 -0.000872
# preferred_device                    0.177208                  0.308645
# city                               -0.114690                 -0.195750
# preferred_category                  1.000000                  0.397787
# total_products_purchased            0.397787                  1.000000
# total_pages_viewed                  0.381150                  0.750459
# average_time_on_site               -0.025574                 -0.029333
# total_review_votes                  0.221867                  0.375622
# preferred_payment_method            0.237637                  0.401211
# rn                                  0.003240                 -0.032756
# churn                              -0.010338                 -0.023029
#
#                           total_pages_viewed  average_time_on_site  \
# customer_id                        -0.005133              0.010810
# total_sessions                      0.844328             -0.013656
# total_orders                        0.398417              0.004388
# total_spend                         0.300064              0.015543
# average_order_value                 0.062238              0.015705
# cart_abandonment_rate              -0.056957              0.019637
# average_discount_used              -0.007870              0.010537
# customer_satisfaction              -0.011773             -0.000125
# preferred_device                    0.307381             -0.071594
# city                               -0.165364             -0.072877
# preferred_category                  0.381150             -0.025574
# total_products_purchased            0.750459             -0.029333
# total_pages_viewed                  1.000000             -0.019955
# average_time_on_site               -0.019955              1.000000
# total_review_votes                  0.374324              0.000897
# preferred_payment_method            0.361230             -0.034661
# rn                                 -0.005188              0.010776
# churn                              -0.050315              0.054528
#
#                           total_review_votes  preferred_payment_method  \
# customer_id                        -0.009475                 -0.029127
# total_sessions                      0.451732                  0.428802
# total_orders                        0.865153                  0.221777
# total_spend                         0.627575                  0.169375
# average_order_value                 0.107155                  0.046351
# cart_abandonment_rate              -0.300534                 -0.098580
# average_discount_used              -0.036809                 -0.071125
# customer_satisfaction              -0.109113                 -0.031076
# preferred_device                    0.164714                  0.199330
# city                               -0.122113                 -0.124488
# preferred_category                  0.221867                  0.237637
# total_products_purchased            0.375622                  0.401211
# total_pages_viewed                  0.374324                  0.361230
# average_time_on_site                0.000897                 -0.034661
# total_review_votes                  1.000000                  0.236857
# preferred_payment_method            0.236857                  1.000000
# rn                                 -0.009670                 -0.029324
# churn                              -0.013205                 -0.056811
#
#                                 rn     churn
# customer_id               0.999993  0.044218
# total_sessions           -0.033364 -0.044759
# total_orders             -0.013317 -0.023584
# total_spend              -0.011658 -0.021681
# average_order_value      -0.013034 -0.007878
# cart_abandonment_rate     0.029248  0.028600
# average_discount_used     0.031422 -0.030715
# customer_satisfaction     0.009926 -0.032281
# preferred_device         -0.011566  0.013417
# city                     -0.003661 -0.012316
# preferred_category        0.003240 -0.010338
# total_products_purchased -0.032756 -0.023029
# total_pages_viewed       -0.005188 -0.050315
# average_time_on_site      0.010776  0.054528
# total_review_votes       -0.009670 -0.013205
# preferred_payment_method -0.029324 -0.056811
# rn                        1.000000  0.044324
# churn                     0.044324  1.000000

# %%
correlation_matrix[
    "churn"
].sort_values(
    ascending=False
)
# Out:
# churn                       1.000000
# average_time_on_site        0.054528
# rn                          0.044324
# customer_id                 0.044218
# cart_abandonment_rate       0.028600
# preferred_device            0.013417
# average_order_value        -0.007878
# preferred_category         -0.010338
# city                       -0.012316
# total_review_votes         -0.013205
# total_spend                -0.021681
# total_products_purchased   -0.023029
# total_orders               -0.023584
# average_discount_used      -0.030715
# customer_satisfaction      -0.032281
# total_sessions             -0.044759
# total_pages_viewed         -0.050315
# preferred_payment_method   -0.056811
# Name: churn, dtype: float64

# %%
top_customers = (
    df.sort_values(
        by="total_spend",
        ascending=False
    )
)

top_customers[
    [
        "customer_id",
        "total_spend",
        "total_orders"
    ]
].head(10)
# Out:
#      customer_id  total_spend  total_orders
# 704         1738     13800.96             3
# 318         1334     12203.21             5
# 481         1506     11867.10             4
# 926         1973     10467.41             2
# 631         1661     10152.52             3
# 301         1316      9432.31             5
# 176         1187      9145.76             2
# 992         2041      8680.05             2
# 580         1608      8634.02             4
# 413         1433      8307.94             2

# %%
churned_customers = df[
    df["churn"] == 1
]

churned_customers.head()
# Out:
#     customer_id  total_sessions  total_orders  total_spend  \
# 39         1040               5             2      7417.69
# 44         1045               2             0         0.00
# 48         1049               4             0         0.00
# 52         1053               1             0         0.00
# 56         1057               4             0         0.00
#
#     average_order_value  cart_abandonment_rate  average_discount_used  \
# 39              3708.85                   0.60                   3.00
# 44              1399.00                   0.50                   5.00
# 48              1399.00                   0.50                  13.75
# 52              1399.00                   0.00                  30.00
# 56              1399.00                   0.25                   3.75
#
#     customer_satisfaction  preferred_device  city  preferred_category  \
# 39                    3.6                 2    83                   7
# 44                    4.0                 1    83                   5
# 48                    4.0                 1    64                   7
# 52                    4.0                 1   130                   1
# 56                    4.0                 1   209                   6
#
#     total_products_purchased  total_pages_viewed  average_time_on_site  \
# 39                        15                  25               1016.00
# 44                         8                  32                868.00
# 48                         8                  53                951.75
# 52                         4                   9               1385.00
# 56                        10                  40               1014.25
#
#     total_review_votes  preferred_payment_method  rn  churn
# 39                  66                         5  40      1
# 44                   0                         3  45      1
# 48                   0                         5  49      1
# 52                   0                         2  53      1
# 56                   0                         4  57      1

# %%
df.to_csv(
    "../datasets/customer_ml_dataset_eda.csv",
    index=False
)
